# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join('..','src')))

# %%
from clustering_library import FeatureEngineer

# %%
data_path='../data/processed/cleaned_uk_data.csv'
engineer=FeatureEngineer(data_path)

# %%
df=engineer.load_data()
customer_features=engineer.create_customer_features()

# %%
print(df)
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 354316     581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 354317     581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 354318     581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 354319     581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 354320     581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...                    ...        ...         ...             ...         ...
# 354316 2011-12-09 12:31:00       1.95     15804.0  United Kingdom       23.40
# 354317 2011-12-09 12:49:00       2.95     13113.0  United Kingdom       23.60
# 354318 2011-12-09 12:49:00       1.25     13113.0  United Kingdom       30.00
# 354319 2011-12-09 12:49:00       8.95     13113.0  United Kingdom      214.80
# 354320 2011-12-09 12:49:00       7.08     13113.0  United Kingdom       70.80
#
#         Hour  DayOfWeek       Date      Month
# 0          8          2 2010-12-01 2010-12-01
# 1          8          2 2010-12-01 2010-12-01
# 2          8          2 2010-12-01 2010-12-01
# 3          8          2 2010-12-01 2010-12-01
# 4          8          2 2010-12-01 2010-12-01
# ...      ...        ...        ...        ...
# 354316    12          4 2011-12-09 2011-12-01
# 354317    12          4 2011-12-09 2011-12-01
# 354318    12          4 2011-12-09 2011-12-01
# 354319    12          4 2011-12-09 2011-12-01
# 354320    12          4 2011-12-09 2011-12-01
#
# [354321 rows x 13 columns]

# %%
print(customer_features)
# Out:
#       CustomerID  Sum_Quantity  Mean_UnitPrice  Mean_TotalPrice  \
# 0        12346.0         74215        1.040000     77183.600000
# 1        12747.0          1275        4.367864        40.737961
# 2        12748.0         25747        2.656279         7.338353
# 3        12749.0          1471        4.999950        20.557186
# 4        12820.0           722        1.904746        15.971864
# ...          ...           ...             ...              ...
# 3915     18280.0            45        4.765000        18.060000
# 3916     18281.0            54        5.622857        11.545714
# 3917     18282.0           103        5.199167        14.837500
# 3918     18283.0          1397        1.614987         2.771005
# 3919     18287.0          1586        1.493571        26.246857
#
#       Sum_TotalPrice  Count_Invoice  Count_Stock  Mean_StockCountPerInvoice  \
# 0           77183.60              1            1                   1.000000
# 1            4196.01             11           42                   9.363636
# 2           33719.73            209         1768                  20.497608
# 3            4090.88              5          160                  39.800000
# 4             942.34              4           55                  14.750000
# ...              ...            ...          ...                        ...
# 3915          180.60              1           10                  10.000000
# 3916           80.82              1            7                   7.000000
# 3917          178.05              2           12                   6.000000
# 3918         2094.88             16          263                  43.062500
# 3919         1837.28              3           59                  22.666667
#
#       Mean_UnitPriceMeanPerInvoice  Mean_QuantitySumPerInvoice  \
# 0                         1.040000                74215.000000
# 1                         4.253949                  115.909091
# 2                         8.916506                  123.191388
# 3                         5.095433                  294.200000
# 4                         1.902633                  180.500000
# ...                            ...                         ...
# 3915                      4.765000                   45.000000
# 3916                      5.622857                   54.000000
# 3917                      5.128429                   51.500000
# 3918                      1.684511                   87.312500
# 3919                      1.269575                  528.666667
#
#       Mean_TotalPriceMeanPerInvoice  Mean_TotalPriceSumPerInvoice  \
# 0                      77183.600000                  77183.600000
# 1                         43.645453                    381.455455
# 2                         16.378101                    161.338421
# 3                         21.871511                    818.176000
# 4                         16.051496                    235.585000
# ...                             ...                           ...
# 3915                      18.060000                    180.600000
# 3916                      11.545714                     80.820000
# 3917                      14.941857                     89.025000
# 3918                       2.795085                    130.930000
# 3919                      25.433164                    612.426667
#
#       Mean_InvoiceCountPerStock  Mean_UnitPriceMeanPerStock  \
# 0                      1.000000                    1.040000
# 1                      2.452381                    4.844583
# 2                      2.423077                    2.726409
# 3                      1.243750                    4.785563
# 4                      1.072727                    1.808727
# ...                         ...                         ...
# 3915                   1.000000                    4.765000
# 3916                   1.000000                    5.622857
# 3917                   1.000000                    5.199167
# 3918                   2.619772                    1.861305
# 3919                   1.152542                    1.553757
#
#       Mean_QuantitySumPerStock  Mean_TotalPriceMeanPerStock  \
# 0                 74215.000000                 77183.600000
# 1                    30.357143                    27.983690
# 2                    14.562783                     8.176556
# 3                     9.193750                    20.025448
# 4                    13.127273                    15.816182
# ...                        ...                          ...
# 3915                  4.500000                    18.060000
# 3916                  7.714286                    11.545714
# 3917                  8.583333                    14.837500
# 3918                  5.311787                     2.840375
# 3919                 26.881356                    24.343051
#
#       Mean_TotalPriceSumPerStack
# 0                   77183.600000
# 1                      99.905000
# 2                      19.072245
# 3                      25.568000
# 4                      17.133455
# ...                          ...
# 3915                   18.060000
# 3916                   11.545714
# 3917                   14.837500
# 3918                    7.965323
# 3919                   31.140339
#
# [3920 rows x 17 columns]

# %%
customer_features_transformed=engineer.transform_features()
# Out:
# d:\Practice ML\Customer segmentation with KMeans\src\clustering_library.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.16428498  7.1309479  10.11472544 ...  4.63572316  7.22173307
#   7.34779257]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# d:\Practice ML\Customer segmentation with KMeans\src\clustering_library.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.53859976 1.11545578 1.29113343 ... 0.74441355 1.16159571 0.8563553 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# d:\Practice ML\Customer segmentation with KMeans\src\clustering_library.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.71303102  4.39899452 10.28845057 ...  2.85170154  7.0529684
#   4.85734799]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.

# %%
engineer.plot_features_histograms(transform=False)

# %%
engineer.plot_features_histograms(transform=True)

# %%
customer_features_scaled=engineer.scale_features()

# %%
engineer.save_featues()
